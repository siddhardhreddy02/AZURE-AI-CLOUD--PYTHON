# %%
# !pip install azure-storage-blob azure-identity
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.24.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-identity
#   Downloading azure_identity-1.19.0-py3-none-any.whl.metadata (80 kB)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Downloading azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-storage-blob) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-storage-blob) (4.12.2)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting msal>=1.30.0 (from azure-identity)
#   Downloading msal-1.31.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.9.0)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=1.2.0->azure-identity)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: pycparser in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity) (308)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vkred\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.8.30)
# Downloading azure_storage_blob-12.24.0-py3-none-any.whl (408 kB)
# Downloading azure_identity-1.19.0-py3-none-any.whl (187 kB)
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.31.1-py3-none-any.whl (113 kB)
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, isodate, azure-core, azure-storage-blob, msal, msal-extensions, azure-identity
# Successfully installed azure-core-1.32.0 azure-identity-1.19.0 azure-storage-blob-12.24.0 isodate-0.7.2 msal-1.31.1 msal-extensions-1.2.0 portalocker-2.10.1

# %%
from azure.storage.blob import BlobServiceClient

# %%
blob_account_url='AZURE URL'
storage_credential='Azure container ACCESS KEY'

blob_service_client=BlobServiceClient(account_url=blob_account_url,credential=storage_credential)

blob_service_client

# %%
new_container=blob_service_client.create_container('vscodecontainer',public_access='container')
new_container

# %%
new_container.get_container_properties()
# Out:
# {'name': 'vscodecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 30, 6, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD1050077D7791"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': {}, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB0BE0F0>, 'immutable_storage_with_versioning_enabled': False}

# %%
#list out all container
all_containers=blob_service_client.list_containers()
all_containers
# Out:
# <iterator object azure.core.paging.ItemPaged at 0x194ab070a40>

# %%
for container in all_containers:
    print(container)
# Out:
# {'name': 'cloudcontainer', 'last_modified': datetime.datetime(2024, 11, 28, 8, 47, 21, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD0F894632226D"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AA3E5F10>, 'immutable_storage_with_versioning_enabled': False}
# {'name': 'imagecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 10, 55, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD104D59AE5684"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AA823380>, 'immutable_storage_with_versioning_enabled': False}
# {'name': 'vscodecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 30, 6, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD1050077D7791"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB0D4D10>, 'immutable_storage_with_versioning_enabled': False}

# %%
all_containers=blob_service_client.list_containers()
list(all_containers)
# Out:
# [{'name': 'cloudcontainer', 'last_modified': datetime.datetime(2024, 11, 28, 8, 47, 21, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD0F894632226D"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB072C00>, 'immutable_storage_with_versioning_enabled': False},
#  {'name': 'imagecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 10, 55, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD104D59AE5684"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB070350>, 'immutable_storage_with_versioning_enabled': False},
#  {'name': 'vscodecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 30, 6, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD1050077D7791"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB072A20>, 'immutable_storage_with_versioning_enabled': False}]

# %%
#delete the container

all_containers=blob_service_client.list_containers()
for container in all_containers:
    print("deleting:",'vscodecontainer')
    blob_service_client.delete_container('vscodecontainer')
# Out:
# deleting: vscodecontainer
# deleting: vscodecontainer

# %%
all_containers=blob_service_client.list_containers()
list(all_containers)
# Out:
# [{'name': 'cloudcontainer', 'last_modified': datetime.datetime(2024, 11, 28, 8, 47, 21, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD0F894632226D"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB071A30>, 'immutable_storage_with_versioning_enabled': False},
#  {'name': 'imagecontainer', 'last_modified': datetime.datetime(2024, 11, 29, 8, 10, 55, tzinfo=datetime.timezone.utc), 'etag': '"0x8DD104D59AE5684"', 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'public_access': 'container', 'has_immutability_policy': False, 'deleted': None, 'version': None, 'has_legal_hold': False, 'metadata': None, 'encryption_scope': <azure.storage.blob._models.ContainerEncryptionScope object at 0x00000194AB0736E0>, 'immutable_storage_with_versioning_enabled': False}]

# %%
#creating the container
blob_account_url='https://azuremlfordata.blob.core.windows.net'
storage_credential='qlTjrZSzJGjHxILpKFabRyegZFNbIFYLfOeHpMGVC80lu6hY05Uf+6Z62I1XIOSZwAowFplvn9Pk+AStB0Nz0w=='

blob_service_client=BlobServiceClient(account_url=blob_account_url, credential=storage_credential)

new_container=blob_service_client.create_container('createcontainer',public_access='container')
new_container

# %%
#uploading a file in the new container
#create a blobclient instance for the specified blob

blob_name = 'simple.txt'
file_path=r"C:\Users\vkred\OneDrive\Documents\sample.txt"
container_client = blob_service_client.get_container_client('createcontainer')
blob_client = container_client.get_blob_client(blob_name)

with open(file_path, 'rb') as data:
    blob_client.upload_blob(data, overwrite=True)

# %%
#uploading a file in the new container
#create a blobclient instance for the specified blob

blob_name = 'cleandata.csv'
file_path=r"C:\Users\vkred\Downloads\clean_data.csv"
container_client = blob_service_client.get_container_client('createcontainer')
blob_client = container_client.get_blob_client(blob_name)

with open(file_path, 'rb') as data:
    blob_client.upload_blob(data, overwrite=True)

# %%
#uploading a file in the new container
#create a blobclient instance for the specified blob

blob_name = 'elephant.jpg'
file_path=r"C:\Users\vkred\Downloads\elephant 1.jpg"
container_client = blob_service_client.get_container_client('createcontainer')
blob_client = container_client.get_blob_client(blob_name)

with open(file_path, 'rb') as data:
    blob_client.upload_blob(data, overwrite=True)

# %%
#Access the blobs

container_client = blob_service_client.get_container_client('createcontainer')
for blob in container_client.list_blobs():
    print(blob)
# Out:
# {'name': 'cleandata.csv', 'container': 'createcontainer', 'snapshot': None, 'version_id': None, 'is_current_version': None, 'blob_type': <BlobType.BLOCKBLOB: 'BlockBlob'>, 'metadata': {}, 'encrypted_metadata': None, 'last_modified': datetime.datetime(2024, 11, 29, 9, 20, 11, tzinfo=datetime.timezone.utc), 'etag': '0x8DD1057066E3269', 'size': 262, 'content_range': None, 'append_blob_committed_block_count': None, 'is_append_blob_sealed': None, 'page_blob_sequence_number': None, 'server_encrypted': True, 'copy': {'id': None, 'source': None, 'status': None, 'progress': None, 'completion_time': None, 'status_description': None, 'incremental_copy': None, 'destination_snapshot': None}, 'content_settings': {'content_type': 'application/octet-stream', 'content_encoding': None, 'content_language': None, 'content_md5': bytearray(b'i\xdb\x7f\x14\xb0\x95\x93)\xb9N(t\xe6\xe8\x9a\xe5'), 'content_disposition': None, 'cache_control': None}, 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'blob_tier': 'Hot', 'rehydrate_priority': None, 'blob_tier_change_time': None, 'blob_tier_inferred': True, 'deleted': None, 'deleted_time': None, 'remaining_retention_days': None, 'creation_time': datetime.datetime(2024, 11, 29, 9, 20, 11, tzinfo=datetime.timezone.utc), 'archive_status': None, 'encryption_key_sha256': None, 'encryption_scope': None, 'request_server_encrypted': None, 'object_replication_source_properties': [], 'object_replication_destination_policy': None, 'last_accessed_on': None, 'tag_count': None, 'tags': None, 'immutability_policy': {'expiry_time': None, 'policy_mode': None}, 'has_legal_hold': None, 'has_versions_only': None}
# {'name': 'elephant.jpg', 'container': 'createcontainer', 'snapshot': None, 'version_id': None, 'is_current_version': None, 'blob_type': <BlobType.BLOCKBLOB: 'BlockBlob'>, 'metadata': {}, 'encrypted_metadata': None, 'last_modified': datetime.datetime(2024, 11, 29, 9, 28, 30, tzinfo=datetime.timezone.utc), 'etag': '0x8DD10582FFB860D', 'size': 170520, 'content_range': None, 'append_blob_committed_block_count': None, 'is_append_blob_sealed': None, 'page_blob_sequence_number': None, 'server_encrypted': True, 'copy': {'id': None, 'source': None, 'status': None, 'progress': None, 'completion_time': None, 'status_description': None, 'incremental_copy': None, 'destination_snapshot': None}, 'content_settings': {'content_type': 'application/octet-stream', 'content_encoding': None, 'content_language': None, 'content_md5': bytearray(b'\x1cK\xdfj\x9a~\x9fR\xa7\xb9 \xfd\xd2\x15\xe7:'), 'content_disposition': None, 'cache_control': None}, 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'blob_tier': 'Hot', 'rehydrate_priority': None, 'blob_tier_change_time': None, 'blob_tier_inferred': True, 'deleted': None, 'deleted_time': None, 'remaining_retention_days': None, 'creation_time': datetime.datetime(2024, 11, 29, 9, 28, 30, tzinfo=datetime.timezone.utc), 'archive_status': None, 'encryption_key_sha256': None, 'encryption_scope': None, 'request_server_encrypted': None, 'object_replication_source_properties': [], 'object_replication_destination_policy': None, 'last_accessed_on': None, 'tag_count': None, 'tags': None, 'immutability_policy': {'expiry_time': None, 'policy_mode': None}, 'has_legal_hold': None, 'has_versions_only': None}
# {'name': 'simple.txt', 'container': 'createcontainer', 'snapshot': None, 'version_id': None, 'is_current_version': None, 'blob_type': <BlobType.BLOCKBLOB: 'BlockBlob'>, 'metadata': {}, 'encrypted_metadata': None, 'last_modified': datetime.datetime(2024, 11, 29, 9, 15, 40, tzinfo=datetime.timezone.utc), 'etag': '0x8DD105664CC8ADE', 'size': 542, 'content_range': None, 'append_blob_committed_block_count': None, 'is_append_blob_sealed': None, 'page_blob_sequence_number': None, 'server_encrypted': True, 'copy': {'id': None, 'source': None, 'status': None, 'progress': None, 'completion_time': None, 'status_description': None, 'incremental_copy': None, 'destination_snapshot': None}, 'content_settings': {'content_type': 'application/octet-stream', 'content_encoding': None, 'content_language': None, 'content_md5': bytearray(b't\xc2\xd7B\x9f?\x91\\[\x1a;e\xde\xc6:z'), 'content_disposition': None, 'cache_control': None}, 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'blob_tier': 'Hot', 'rehydrate_priority': None, 'blob_tier_change_time': None, 'blob_tier_inferred': True, 'deleted': None, 'deleted_time': None, 'remaining_retention_days': None, 'creation_time': datetime.datetime(2024, 11, 29, 9, 15, 40, tzinfo=datetime.timezone.utc), 'archive_status': None, 'encryption_key_sha256': None, 'encryption_scope': None, 'request_server_encrypted': None, 'object_replication_source_properties': [], 'object_replication_destination_policy': None, 'last_accessed_on': None, 'tag_count': None, 'tags': None, 'immutability_policy': {'expiry_time': None, 'policy_mode': None}, 'has_legal_hold': None, 'has_versions_only': None}

# %%
#Access the csv data

blob_client=blob_service_client.get_blob_client('createcontainer','cleandata.csv')
data = blob_client.download_blob()
import pandas as pd
pd.read_csv(data)
# Out:
#    Unnamed: 0   Name       Domain  Age   Location  Salary  Exp
# 0           0   Mike  Datascience   34     Mumbai    5000    2
# 1           1  Teddy      Testing   45  Bangalore   10000    3
# 2           2   Umar  Dataanalyst   50  Bangalore   15000    4
# 3           3   Jane    Analytics   50   Hyderbad   20000    4
# 4           4  Uttam   Statistics   67  Bangalore   30000    5
# 5           5    Kim          NLP   55      Delhi   60000   10

# %%
blob_client=blob_service_client.get_blob_client('createcontainer','elephant.jpg')
data = blob_client.download_blob()
from PIL import Image
Image.open(data)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=735x1000>
